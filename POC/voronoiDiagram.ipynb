# %%
from mplsoccer import Pitch, Sbopen
import matplotlib.pyplot as plt

# France vs Poland
MATCH_ID = 3869152

# get event and freeze frame data for game 7478
parser = Sbopen()
events, related, freeze, players = parser.event(MATCH_ID)

# %%
related
# Out:
#       match_id                                    id  index     type_name  \
# 0      3869152  35faf830-4fc9-4df5-8429-a11795bdcd13      3    Half Start
# 1      3869152  deb5b9c2-54fa-4b5f-85c9-d3ba6e555781      4    Half Start
# 2      3869152  df1e38a8-9d45-47c2-9f7a-7652b6cc42eb      5          Pass
# 3      3869152  5a891b0c-64db-43bb-bbdc-101fa0346bce      6  Ball Receipt
# 4      3869152  0856a6fa-e09c-4990-bff9-355d47308918      7         Carry
# ...        ...                                   ...    ...           ...
# 4977   3869152  bf12b01a-ca3f-4f76-941d-c6b636419608   3603          Pass
# 4980   3869152  8a2ddd04-bfdd-4790-8c8a-5e15050684d0   3606          Pass
# 4981   3869152  aaa58678-0c18-44e6-839a-c378029ce5f8   3604  Ball Receipt
# 4988   3869152  48a8b69d-d297-4723-a7d7-18648af18213   3608  Ball Receipt
# 4990   3869152  e8ac94e5-10b3-43ca-ac24-a3df6f9f5a12   3610          Pass
#
#                                 id_related  index_related type_name_related
# 0     deb5b9c2-54fa-4b5f-85c9-d3ba6e555781              4        Half Start
# 1     35faf830-4fc9-4df5-8429-a11795bdcd13              3        Half Start
# 2     5a891b0c-64db-43bb-bbdc-101fa0346bce              6      Ball Receipt
# 3     df1e38a8-9d45-47c2-9f7a-7652b6cc42eb              5              Pass
# 4     1ebe5720-4d89-438e-b628-517d1c446f4a              8              Pass
# ...                                    ...            ...               ...
# 4977  06845f28-eebc-41c0-a57a-fd5a3db1da89           3602             Carry
# 4980  5085800c-d42e-467d-8504-2fe821cfa932           3605             Carry
# 4981  5085800c-d42e-467d-8504-2fe821cfa932           3605             Carry
# 4988  d7d9fc6d-f73b-492b-bea8-5558d487219f           3609             Carry
# 4990  d7d9fc6d-f73b-492b-bea8-5558d487219f           3609             Carry
#
# [6726 rows x 7 columns]

# %%
frames, visible = parser.event(MATCH_ID)
