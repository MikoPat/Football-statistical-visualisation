# %%
from mplsoccer import Pitch, Sbopen
import matplotlib.pyplot as plt

# France vs Poland
MATCH_ID = 3869152

# get event and freeze frame data for game 7478
parser = Sbopen()
#df, players, freeze, tactics  = parser.event(MATCH_ID)

df, related, freeze, players = parser.event(MATCH_ID)

# %%
df.columns
# Out:
# Index(['id', 'index', 'period', 'timestamp', 'minute', 'second', 'possession',
#        'duration', 'match_id', 'type_id', 'type_name', 'possession_team_id',
#        'possession_team_name', 'play_pattern_id', 'play_pattern_name',
#        'team_id', 'team_name', 'tactics_formation', 'player_id', 'player_name',
#        'position_id', 'position_name', 'pass_recipient_id',
#        'pass_recipient_name', 'pass_length', 'pass_angle', 'pass_height_id',
#        'pass_height_name', 'end_x', 'end_y', 'body_part_id', 'body_part_name',
#        'sub_type_id', 'sub_type_name', 'x', 'y', 'outcome_id', 'outcome_name',
#        'under_pressure', 'aerial_won', 'out', 'off_camera',
#        'foul_committed_advantage', 'foul_won_advantage', 'pass_switch',
#        'pass_assisted_shot_id', 'pass_shot_assist', 'technique_id',
#        'technique_name', 'shot_statsbomb_xg', 'end_z', 'shot_key_pass_id',
#        'goalkeeper_position_id', 'goalkeeper_position_name', 'counterpress',
#        'block_deflection', 'pass_cross', 'foul_won_defensive', 'pass_cut_back',
#        'shot_first_time', 'foul_committed_card_id', 'foul_committed_card_name',
#        'block_save_block', 'pass_goal_assist', 'pass_miscommunication',
#        'pass_no_touch', 'substitution_replacement_id',
#        'substitution_replacement_name', 'ball_recovery_recovery_failure',
#        'foul_committed_penalty'],
#       dtype='object')

# %%
df.groupby('type_name').id.unique()
# Out:
# type_name
# Ball Receipt      [5a891b0c-64db-43bb-bbdc-101fa0346bce, a2b6155...
# Ball Recovery     [536953e2-750d-4f89-a67d-87fd96631aad, fa4877f...
# Block             [d33d763c-4ffb-44f2-a096-a7f69ac44144, 480a75a...
# Carry             [0856a6fa-e09c-4990-bff9-355d47308918, 099b8ff...
# Clearance         [42e89997-057f-48d0-8878-b0385adf870e, f4efe5c...
# Dispossessed      [53a63ce3-45d2-4977-acb9-abe94fdb48ad, 9ed472d...
# Dribble           [3f7f2b63-587d-47d0-b623-c4d75833e63c, c776839...
# Dribbled Past     [3cf59af6-7605-46b4-82d3-117f70ebd2dc, d676e53...
# Duel              [6f27c8d7-cc46-4d6b-852d-fae212e91c48, e921285...
# Foul Committed    [bac63953-746d-4838-929b-67a0b5469641, ed754bb...
# Foul Won          [2c3f941b-ce7e-4d2b-9a2a-ecf4a91ad04c, 7ce84db...
# Goal Keeper       [0bc18135-4a3e-409c-8c73-cf33ccbdbe13, 5c2a25f...
# Half End          [1079d4af-478d-49a6-9fde-902899e21d6a, 2321375...
# Half Start        [35faf830-4fc9-4df5-8429-a11795bdcd13, deb5b9c...
# Interception      [299909b1-c7c3-444f-bf86-fe18c03480d7, 5cdaafc...
# Miscontrol        [1a658fc8-5fb9-4faf-8897-aecb4504dfeb, 25ca05c...
# Offside                      [4e73c578-5f05-4ddc-9a3a-41bd6342d4c4]
# Pass              [df1e38a8-9d45-47c2-9f7a-7652b6cc42eb, 1ebe572...
# Pressure          [06086df4-0c2e-4be2-af5e-c1bab0b077c7, d6e4cc3...
# Shield                       [cc4a947b-ff89-4914-9050-9884ff9ca865]
# Shot              [31fad68d-426e-4288-89c0-71ba4c143506, 7cd0dae...
# Starting XI       [a4625118-fe93-450a-9ac3-ee01ce399a22, 0ce4fd9...
# Substitution      [f9b3a069-829d-4575-a220-29d1ebfc131c, 2fdd46a...
# Tactical Shift    [d096d74f-c038-4bb2-8bd1-8f2225d99d7b, 3eb1104...
# Name: id, dtype: object

# %%
df = df[(df.type_name == 'Ball Recovery')].copy()

# %%
pitch = Pitch()
fig, ax = pitch.draw(figsize=(8, 6))
hull = pitch.convexhull(df.x, df.y)
poly = pitch.polygon(hull, ax=ax, edgecolor='cornflowerblue', facecolor='cornflowerblue', alpha=0.3)
scatter = pitch.scatter(df.x, df.y, ax=ax, edgecolor='black', facecolor='cornflowerblue')
plt.show()  # if you are not using a Jupyter notebook this is necessary to show the plot
