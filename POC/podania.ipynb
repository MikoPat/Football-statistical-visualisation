# %%
from mplsoccer import Pitch, FontManager, Sbopen, VerticalPitch
import numpy as np
from matplotlib.colors import to_rgba
import pandas as pd
from matplotlib import pyplot as plt

# %%
# Arg vs Poland
MATCH_ID = 3857264
TEAM = 'Poland'
parser = Sbopen()
events, related, freeze, players = parser.event(MATCH_ID)

# %%
events
# Out:
#                                         id  index  period        timestamp  \
# 0     bad01947-5491-406e-bbe9-2a146161aa70      1       1         00:00:00
# 1     5b336aa1-8a01-4877-916f-4087379ac7bb      2       1         00:00:00
# 2     93e64c47-c329-4d6d-aa73-6ed3df33878a      3       1         00:00:00
# 3     94ef07fc-382f-4646-8f8d-853081be73c8      4       1         00:00:00
# 4     a98cb7b0-0188-4d18-88f8-d6d945ed21a5      5       1  00:00:00.321000
# ...                                    ...    ...     ...              ...
# 4047  ea540c5d-ee20-4768-b9d1-2be74295cbd2   4048       2  00:50:58.498000
# 4048  cd938c60-4751-469d-b42b-19e3b6af45a1   4049       2  00:50:58.498000
# 4049  f4c11442-270f-4a2e-9b7c-bb645af3d33e   4050       2  00:50:59.763000
# 4050  73892e7f-a9ea-4b81-ae06-9682d78b35a4   4051       2  00:51:01.633000
# 4051  d85ba54d-ddc1-4462-9359-8ad7708a9ac6   4052       2  00:51:01.633000
#
#       minute  second  possession  duration  match_id  type_id  ...  \
# 0          0       0           1  0.000000   3857264       35  ...
# 1          0       0           1  0.000000   3857264       35  ...
# 2          0       0           1  0.000000   3857264       18  ...
# 3          0       0           1  0.000000   3857264       18  ...
# 4          0       0           2  1.955771   3857264       30  ...
# ...      ...     ...         ...       ...       ...      ...  ...
# 4047      95      58         132       NaN   3857264       42  ...
# 4048      95      58         132  1.264487   3857264       43  ...
# 4049      95      59         132  1.869968   3857264       30  ...
# 4050      96       1         132  0.000000   3857264       34  ...
# 4051      96       1         132  0.000000   3857264       34  ...
#
#      dribble_overrun  ball_recovery_offensive substitution_replacement_id  \
# 0                NaN                      NaN                         NaN
# 1                NaN                      NaN                         NaN
# 2                NaN                      NaN                         NaN
# 3                NaN                      NaN                         NaN
# 4                NaN                      NaN                         NaN
# ...              ...                      ...                         ...
# 4047             NaN                      NaN                         NaN
# 4048             NaN                      NaN                         NaN
# 4049             NaN                      NaN                         NaN
# 4050             NaN                      NaN                         NaN
# 4051             NaN                      NaN                         NaN
#
#       substitution_replacement_name pass_goal_assist  foul_committed_card_id  \
# 0                               NaN              NaN                     NaN
# 1                               NaN              NaN                     NaN
# 2                               NaN              NaN                     NaN
# 3                               NaN              NaN                     NaN
# 4                               NaN              NaN                     NaN
# ...                             ...              ...                     ...
# 4047                            NaN              NaN                     NaN
# 4048                            NaN              NaN                     NaN
# 4049                            NaN              NaN                     NaN
# 4050                            NaN              NaN                     NaN
# 4051                            NaN              NaN                     NaN
#
#      foul_committed_card_name pass_no_touch  dribble_nutmeg block_save_block
# 0                         NaN           NaN             NaN              NaN
# 1                         NaN           NaN             NaN              NaN
# 2                         NaN           NaN             NaN              NaN
# 3                         NaN           NaN             NaN              NaN
# 4                         NaN           NaN             NaN              NaN
# ...                       ...           ...             ...              ...
# 4047                      NaN           NaN             NaN              NaN
# 4048                      NaN           NaN             NaN              NaN
# 4049                      NaN           NaN             NaN              NaN
# 4050                      NaN           NaN             NaN              NaN
# 4051                      NaN           NaN             NaN              NaN
#
# [4052 rows x 75 columns]

# %%
passes_h = events.loc[(events.team_name == TEAM) & (events.type_name == 'Pass') & (events.x >= 60)]
passes_3 = events.loc[(events.team_name == TEAM) & (events.type_name == 'Pass') & (events.x >= 85)]

# %%
print(len(passes_h))
print(len(passes_3))
# Out:
# 95
# 19

# %%
pitch = VerticalPitch(pitch_type='statsbomb', pitch_color='#22314E', line_color='#efefef')
fig, ax = pitch.draw(figsize=(4.4, 6.4), constrained_layout=True, tight_layout=False)
fig.set_facecolor("#22314E")


pass_nodes = pitch.scatter(passes_3.x, passes_3.y,
                           s=50,
                           color='#1EA8BD', edgecolors='#1EA8BD', linewidth=1, alpha=1, ax=ax)
